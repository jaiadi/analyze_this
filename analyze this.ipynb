# %%
import os

# %%
os.chdir("C:\Anaconda\Scripts")

# %%
import pandas as pd

# %%
df=pd.read_csv("analyze_train.csv")
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    application_key mvar1   mvar2  mvar3  mvar4  mvar5    mvar6  mvar7  \
# 0           230032  1696  1.6541  0.000    0.0    0.0        0   6015
# 1           230033  1846  0.8095  0.000    0.0    0.0      102   7532
# 2           230034  1745  0.4001  0.000    0.0    0.0  missing   2536
# 3           230035  1739  0.2193  0.000    0.0    0.0     1982  26440
# 4           230036  1787  0.0118  0.225    0.0    0.0     5451   5494
#
#      mvar8    mvar9     ...     mvar39   mvar40   mvar41   mvar42  mvar43  \
# 0      322    40369     ...          1    73.78   82.547  0.08696      10
# 1     3171    18234     ...          0   99.129  missing        0      13
# 2  missing  missing     ...          0  missing    29.29        0       1
# 3     4955    20316     ...          0   96.272  missing  0.15385       3
# 4     5494     7987     ...          0  115.019  missing        0       1
#
#     mvar44 mvar45 mvar46 mvar47 default_ind
# 0  0.63899     na      0      C           0
# ...

# %%
df.dtypes
# Out:
# application_key      int64
# mvar1               object
# mvar2              float64
# mvar3              float64
# mvar4              float64
# mvar5              float64
# mvar6               object
# mvar7               object
# mvar8               object
# mvar9               object
# mvar10              object
# mvar11              object
# mvar12              object
# mvar13              object
# mvar14               int64
# mvar15              object
# mvar16              object
# mvar17              object
# mvar18              object
# mvar19              object
# mvar20              object
# mvar21             float64
# mvar22             float64
# mvar23             float64
# mvar24             float64
# mvar25              object
# mvar26              object
# mvar27              object
# mvar28              object
# mvar29              object
# mvar30              object
# mvar31              object
# mvar32              object
# mvar33             float64
# ...

# %%
df.isnull().sum()
# Out:
# application_key        0
# mvar1                  0
# mvar2               5553
# mvar3                501
# mvar4                501
# mvar5                501
# mvar6                  0
# mvar7                  0
# mvar8                  0
# mvar9                  0
# mvar10                 0
# mvar11                 0
# mvar12                 0
# mvar13                 0
# mvar14                 0
# mvar15                 0
# mvar16                 0
# mvar17                 0
# mvar18                 0
# mvar19                 0
# mvar20                 0
# mvar21             22561
# mvar22             29124
# mvar23             40248
# mvar24             18902
# mvar25                 0
# mvar26                 0
# mvar27                 0
# mvar28                 0
# mvar29                 0
# mvar30                 0
# mvar31                 0
# mvar32                 0
# mvar33              1751
# mvar34                 0
# mvar35                 0
# mvar36                 0
# ...

# %%
df.mvar22.median()
# Out:
# 3974.425

# %%
df.corr()
# Out:
#                  application_key     mvar2     mvar3     mvar4     mvar5  \
# application_key         1.000000  0.060180  0.002410  0.015333  0.012062
# mvar2                   0.060180  1.000000  0.119156  0.086873  0.039322
# mvar3                   0.002410  0.119156  1.000000  0.368939  0.658109
# mvar4                   0.015333  0.086873  0.368939  1.000000  0.091933
# mvar5                   0.012062  0.039322  0.658109  0.091933  1.000000
# mvar14                  0.000195 -0.003943 -0.000579 -0.000843 -0.002412
# mvar21                  0.033073  0.231543  0.229255  0.141211  0.092308
# mvar22                  0.033458  0.193542  0.206792  0.118664  0.095217
# mvar23                  0.021471  0.188093  0.197830  0.108777  0.093450
# mvar24                  0.003582  0.039911  0.250980  0.062327  0.039031
# mvar33                 -0.006846 -0.124796 -0.105729 -0.074273 -0.066537
# mvar44                 -0.012773 -0.089405 -0.018925  0.001213 -0.067406
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.mvar3,df.mvar5)

# %%
import seaborn as sns

# %%
sns.boxplot(df.mvar22)

# %%
plt.hist(df.mvar2,bins=10,range=(df.mvar2.min(),df.mvar2.max()))
# Out:
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([7.1573e+04, 2.3640e+03, 3.7800e+02, 9.2000e+01, 2.4000e+01,
#         1.2000e+01, 2.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([ 0.     ,  4.46301,  8.92602, 13.38903, 17.85204, 22.31505,
#         26.77806, 31.24107, 35.70408, 40.16709, 44.6301 ]),
#  <a list of 10 Patch objects>)

# %%
df.mvar2
# Out:
# 0        1.6541
# 1        0.8095
# 2        0.4001
# 3        0.2193
# 4        0.0118
# 5           NaN
# 6        0.4001
# 7           NaN
# 8        0.1358
# 9        0.1981
# 10       0.0000
# 11       1.5888
# 12       0.5388
# 13       1.9684
# 14       3.8558
# 15       3.0284
# 16       0.0970
# 17       8.7747
# 18       0.8601
# 19       0.0155
# 20       2.6101
# 21       3.6201
# 22       3.0268
# 23       0.0401
# 24       0.2251
# 25       0.0318
# 26       0.3993
# 27       0.3276
# 28       5.1904
# 29       2.0457
#           ...
# 79970    1.2164
# 79971    1.3696
# 79972    5.8283
# 79973    1.9635
# 79974    1.7588
# 79975    0.9540
# 79976    0.0000
# 79977    0.5634
# 79978    0.0544
# 79979    2.6649
# 79980    0.5851
# 79981    0.1828
# 79982    3.1701
# 79983    0.1380
# 79984    0.1221
# 79985    0.0347
# 79986    0.1782
# 79987    0.5372
# 79988    0.0410
# 79989    0.1451
# 79990    0.4834
# 79991       NaN
# 79992    2.0999
# 79993    0.3831
# ...

# %%
from scipy.stats import spearmanr,kruskal

# %%
df.mvar2.median()
# Out:
# 0.5389

# %%
df1=df.copy()

# %%
df1.mvar2.fillna(df1.mvar2.median(),inplace=True)

# %%
df1[df1.default_ind==0].mvar2.mean() ,df1[df1.default_ind==1].mvar2.mean()
# Out:
# (0.8580226804636274, 1.7039115855206264)

# %%
plt.hist(df1.mvar2,bins=100)
# Out:
# (array([3.4074e+04, 1.8018e+04, 7.6240e+03, 5.8450e+03, 3.7870e+03,
#         2.6860e+03, 1.9710e+03, 1.3880e+03, 1.0250e+03, 7.0800e+02,
#         5.6600e+02, 4.4000e+02, 3.1200e+02, 2.5400e+02, 2.3700e+02,
#         1.5300e+02, 1.2000e+02, 1.1200e+02, 1.0000e+02, 7.0000e+01,
#         7.4000e+01, 6.0000e+01, 5.2000e+01, 3.4000e+01, 3.9000e+01,
#         3.0000e+01, 2.4000e+01, 2.4000e+01, 2.2000e+01, 1.9000e+01,
#         1.3000e+01, 1.3000e+01, 1.2000e+01, 1.0000e+01, 1.0000e+01,
#         1.0000e+01, 7.0000e+00, 7.0000e+00, 6.0000e+00, 4.0000e+00,
#         4.0000e+00, 0.0000e+00, 3.0000e+00, 1.0000e+00, 3.0000e+00,
#         3.0000e+00, 2.0000e+00, 1.0000e+00, 2.0000e+00, 5.0000e+00,
#         1.0000e+00, 1.0000e+00, 2.0000e+00, 0.0000e+00, 4.0000e+00,
#         3.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
# ...

# %%
df[df.mvar10=='missing'].mvar10.value_counts()
# Out:
# missing    502
# Name: mvar10, dtype: int64

# %%
import numpy as np

# %%
def repfiller(column):
    column.replace(to_replace='missing',value=np.nan,inplace=True)

# %%
repfiller(df1.mvar6)

# %%
df1.mvar6=df1.mvar6.astype(float)

# %%
plt.hist(df1.mvar6,bins=100,range=(df1.mvar6.min(),df1.mvar6.max()))
# Out:
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([4.5866e+04, 5.4680e+03, 2.7560e+03, 2.0340e+03, 1.0650e+03,
#         9.1700e+02, 5.7900e+02, 5.8900e+02, 3.1900e+02, 2.5000e+02,
#         3.0400e+02, 1.7500e+02, 1.0800e+02, 1.1900e+02, 1.0200e+02,
#         6.8000e+01, 4.8000e+01, 6.3000e+01, 4.3000e+01, 2.6000e+01,
#         1.3000e+01, 2.8000e+01, 8.0000e+00, 1.0000e+01, 6.0000e+00,
#         5.0000e+00, 9.0000e+00, 4.0000e+00, 3.0000e+00, 3.0000e+00,
#         1.1000e+01, 6.0000e+00, 4.0000e+00, 6.0000e+00, 3.0000e+00,
#         1.0000e+00, 5.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
# ...

# %%
df1.mvar6.fillna(df1.mvar6.median(),inplace=True)

# %%
df1.columns
# Out:
# Index(['application_key', 'mvar1', 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6',
#        'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
#        'mvar14', 'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20',
#        'mvar21', 'mvar22', 'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar27',
#        'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar33', 'mvar34',
#        'mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39', 'mvar40', 'mvar41',
#        'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47',
#        'default_ind'],
#       dtype='object')

# %%
object_col=['mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
        'mvar15', 
        'mvar25', 'mvar26', 'mvar27',
       'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar34',
      'mvar40', 'mvar41',
       'mvar42']
object_col1=['mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20']
object_col2=['mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39']

# %%
for i in object_col:
    df1[i].replace(to_replace='missing',value=np.nan,inplace=True)

# %%
df1.mvar43.replace(to_replace='na',value=np.nan,inplace=True)
df1.mvar45.replace(to_replace='na',value=np.nan,inplace=True)
df1.mvar46.replace(to_replace='na',value=np.nan,inplace=True)

# %%
df1.isnull().sum()
# Out:
# application_key        0
# mvar1                  0
# mvar2                  0
# mvar3                501
# mvar4                501
# mvar5                501
# mvar6                  0
# mvar7               7394
# mvar8              18964
# mvar9              11408
# mvar10               502
# mvar11             44819
# mvar12             14078
# mvar13              8352
# mvar14                 0
# mvar15             32067
# mvar16                 0
# mvar17                 0
# mvar18                 0
# mvar19                 0
# mvar20                 0
# mvar21             22561
# mvar22             29124
# mvar23             40248
# mvar24             18902
# mvar25              7706
# mvar26             10610
# mvar27             13209
# mvar28               502
# mvar29               502
# mvar30             36417
# mvar31             56218
# mvar32              7706
# mvar33              1751
# mvar34                 0
# mvar35                 0
# mvar36                 0
# ...

# %%
df1.mvar17.value_counts()
# Out:
# 0     52719
# na    15846
# 1      8042
# 2      2150
# 3       725
# 4       286
# 5       124
# 6        42
# 7        35
# 8        12
# 9         7
# 10        5
# 11        3
# 13        2
# 21        1
# 16        1
# Name: mvar17, dtype: int64

# %%
for i in object_col1:
    df1[i].replace(to_replace='na',value=np.nan,inplace=True)

# %%
df1.isnull().sum()
# Out:
# application_key        0
# mvar1                  0
# mvar2                  0
# mvar3                501
# mvar4                501
# mvar5                501
# mvar6                  0
# mvar7               7394
# mvar8              18964
# mvar9              11408
# mvar10               502
# mvar11             44819
# mvar12             14078
# mvar13              8352
# mvar14                 0
# mvar15             32067
# mvar16             18510
# mvar17             15846
# mvar18             14771
# mvar19                 4
# mvar20               502
# mvar21             22561
# mvar22             29124
# mvar23             40248
# mvar24             18902
# mvar25              7706
# mvar26             10610
# mvar27             13209
# mvar28               502
# mvar29               502
# mvar30             36417
# mvar31             56218
# mvar32              7706
# mvar33              1751
# mvar34                 0
# mvar35                 0
# mvar36                 0
# ...

# %%
for i in object_col1:
    df1[i]=df1[i].astype(float)

# %%
for i in object_col2:
    df1[i].replace(to_replace='na',value=np.nan,inplace=True)

# %%
for i in object_col2:
    df1[i]=df1[i].astype(float)

# %%
df1.dtypes
# Out:
# application_key      int64
# mvar1               object
# mvar2              float64
# mvar3              float64
# mvar4              float64
# mvar5              float64
# mvar6              float64
# mvar7              float64
# mvar8              float64
# mvar9              float64
# mvar10             float64
# mvar11             float64
# mvar12             float64
# mvar13             float64
# mvar14               int64
# mvar15             float64
# mvar16             float64
# mvar17             float64
# mvar18             float64
# mvar19             float64
# mvar20             float64
# mvar21             float64
# mvar22             float64
# mvar23             float64
# mvar24             float64
# mvar25             float64
# mvar26             float64
# mvar27             float64
# mvar28             float64
# mvar29             float64
# mvar30             float64
# mvar31             float64
# mvar32             float64
# mvar33             float64
# ...

# %%
df1.mvar34.replace(to_replace='na',value=np.nan,inplace=True)

# %%
object_col3=['mvar34','mvar40', 'mvar41',
       'mvar42', 'mvar43', 'mvar45', 'mvar46']

# %%
for i in object_col3:
    df1[i]=df1[i].astype(float)

# %%
df1.dtypes
# Out:
# application_key      int64
# mvar1               object
# mvar2              float64
# mvar3              float64
# mvar4              float64
# mvar5              float64
# mvar6              float64
# mvar7              float64
# mvar8              float64
# mvar9              float64
# mvar10             float64
# mvar11             float64
# mvar12             float64
# mvar13             float64
# mvar14               int64
# mvar15             float64
# mvar16             float64
# mvar17             float64
# mvar18             float64
# mvar19             float64
# mvar20             float64
# mvar21             float64
# mvar22             float64
# mvar23             float64
# mvar24             float64
# mvar25             float64
# mvar26             float64
# mvar27             float64
# mvar28             float64
# mvar29             float64
# mvar30             float64
# mvar31             float64
# mvar32             float64
# mvar33             float64
# ...

# %%
df1.corr()
# Out:
#                  application_key     mvar2     mvar3     mvar4     mvar5  \
# application_key         1.000000  0.059568  0.002410  0.015333  0.012062
# mvar2                   0.059568  1.000000  0.120588  0.089379  0.039659
# mvar3                   0.002410  0.120588  1.000000  0.368939  0.658109
# mvar4                   0.015333  0.089379  0.368939  1.000000  0.091933
# mvar5                   0.012062  0.039659  0.658109  0.091933  1.000000
# mvar6                  -0.011679 -0.145104 -0.128999 -0.074241 -0.051028
# mvar7                   0.001517 -0.096825 -0.084982 -0.045899 -0.048359
# mvar8                  -0.012109 -0.203589 -0.202675 -0.111535 -0.072506
# mvar9                   0.006919 -0.157560 -0.200606 -0.118342 -0.086020
# mvar10                  0.000602 -0.120536 -0.146626 -0.074592 -0.072473
# mvar11                 -0.013886  0.033794  0.263732  0.042771  0.198875
# mvar12                  0.015306 -0.020360 -0.143968 -0.073101 -0.062461
# ...

# %%
df1.isnull().sum()
# Out:
# application_key        0
# mvar1                  0
# mvar2                  0
# mvar3                501
# mvar4                501
# mvar5                501
# mvar6                  0
# mvar7               7394
# mvar8              18964
# mvar9              11408
# mvar10               502
# mvar11             44819
# mvar12             14078
# mvar13              8352
# mvar14                 0
# mvar15             32067
# mvar16             18510
# mvar17             15846
# mvar18             14771
# mvar19                 4
# mvar20               502
# mvar21             22561
# mvar22             29124
# mvar23             40248
# mvar24             18902
# mvar25              7706
# mvar26             10610
# mvar27             13209
# mvar28               502
# mvar29               502
# mvar30             36417
# mvar31             56218
# mvar32              7706
# mvar33              1751
# mvar34               502
# mvar35             33014
# mvar36              2898
# ...

# %%
plt.hist(df1.mvar3,bins=100,range=(df1.mvar3.min(),df1.mvar3.max()))
# Out:
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([5.2765e+04, 5.3360e+03, 6.0570e+03, 3.0050e+03, 2.5720e+03,
#         2.1590e+03, 1.4630e+03, 1.2420e+03, 9.0800e+02, 7.5900e+02,
#         6.0600e+02, 4.8700e+02, 3.9600e+02, 3.0600e+02, 2.5100e+02,
#         1.9400e+02, 1.3800e+02, 1.3000e+02, 8.5000e+01, 9.5000e+01,
#         7.6000e+01, 5.7000e+01, 5.6000e+01, 3.8000e+01, 5.2000e+01,
#         4.2000e+01, 2.8000e+01, 2.4000e+01, 3.0000e+01, 1.6000e+01,
#         1.3000e+01, 1.6000e+01, 1.1000e+01, 1.2000e+01, 1.2000e+01,
#         8.0000e+00, 5.0000e+00, 3.0000e+00, 5.0000e+00, 8.0000e+00,
#         2.0000e+00, 6.0000e+00, 1.0000e+00, 2.0000e+00, 1.0000e+00,
# ...

# %%
df1.mvar11.mean()
# Out:
# 5342.149739916432

# %%
df1.mvar1.replace(to_replace='na',value=np.nan,inplace=True)
df1.mvar1=df1.mvar1.astype(float)

# %%
df2=df1.copy()

# %%
from sklearn.preprocessing import Imputer
imp=Imputer(missing_values='NaN',strategy='median',axis=0)

# %%
df1.columns
# Out:
# Index(['application_key', 'mvar1', 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6',
#        'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
#        'mvar14', 'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20',
#        'mvar21', 'mvar22', 'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar27',
#        'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar33', 'mvar34',
#        'mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39', 'mvar40', 'mvar41',
#        'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47',
#        'default_ind'],
#       dtype='object')

# %%
col_isna=[ 'mvar1','mvar3', 'mvar4', 'mvar5',
       'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
       'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20',
       'mvar21', 'mvar22', 'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar27',
       'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar33', 'mvar34',
       'mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39', 'mvar40', 'mvar41',
       'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46']

# %%
df2.loc[:,col_isna]=imp.fit_transform(df2.loc[:,col_isna])

# %%
import xgboost as xgb

# %%
df2.drop(columns='application_key',inplace=True)

# %%
df2=pd.get_dummies(df2,columns=['mvar47'],drop_first=True)

# %%
df2.mvar42.value_counts()
# Out:
# 0.00000    24305
# 1.00000     3484
# 0.20000     2854
# 0.50000     2156
# 0.33333     1582
# 0.25000     1276
# 0.66667     1217
# 0.16667      868
# 0.75000      828
# 0.40000      793
# 0.14286      775
# 0.60000      694
# 0.12500      644
# 0.28571      611
# 0.80000      598
# 0.11111      588
# 0.10000      557
# 0.42857      534
# 0.09091      501
# 0.37500      479
# 0.83333      478
# 0.22222      445
# 0.08333      435
# 0.07692      433
# 0.57143      433
# 0.85714      413
# 0.07143      395
# 0.71429      377
# 0.18182      376
# 2.00000      374
#            ...
# 0.44262        1
# 0.14085        1
# 0.39344        1
# 0.67347        1
# 0.78667        1
# 0.54902        1
# 0.01176        1
# 0.26154        1
# 0.18987        1
# 0.33929        1
# 0.47170        1
# 0.27160        1
# 0.95918        1
# 0.25758        1
# 0.54348        1
# 0.08537        1
# 0.29688        1
# 0.63235        1
# 0.51111        1
# 0.80556        1
# 0.41071        1
# ...

# %%
df2.mvar46.value_counts()
# Out:
# 0.0     75170
# 1.0      4259
# 2.0       506
# 3.0        54
# 4.0         6
# 5.0         3
# 19.0        1
# 9.0         1
# Name: mvar46, dtype: int64

# %%
x_df2=df2.loc[:,df2.columns!='default_ind']
y_df2=df2.loc[:,'default_ind']

# %%
params={}
params["objective"] ="binary:logistic"
params["booster"]="gbtree"
params["learning_rate"] = 0.05
params["min_child_weight"] = 6
params["subsample"] = 0.8
params["colsample_bytree"] = 0.8
params["silent"] = 1
params["max_depth"] = 6
params["seed"] = 0
plst=list(params.items())

# %%
xgtrain_df2 = xgb.DMatrix(x_df2, label=y_df2)

# %%
model=xgb.train(plst,xgtrain_df2,num_boost_round=500)

# %%
lead1=pd.read_csv("analyze_validation.csv")
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
lead1.head()
# Out:
#    application_key mvar1   mvar2  mvar3  mvar4  mvar5    mvar6    mvar7  \
# 0           350053  1753  0.5001  0.000    0.0    0.0      206    19179
# 1           350054  1894  1.9701  0.000    0.0    0.0      297    19820
# 2           350055  1774  0.1718  0.000    0.0    0.0      197     2563
# 3           350056  1586  0.1123  5.299    0.0    0.0  missing  missing
# 4           350057  1832  1.4442  0.000    0.0    0.0      179     7577
#
#      mvar8    mvar9  ...   mvar38 mvar39   mvar40   mvar41   mvar42 mvar43  \
# 0      206    14221  ...        1      0  missing   20.551  0.42105      3
# 1    19820   176895  ...        3      0  missing   63.047        0     15
# 2      877     8869  ...        1      0  missing   83.797  0.33333      3
# 3  missing  missing  ...        1     na  missing  missing      1.5      0
# 4      179    21059  ...        3      0   96.052   66.665        0     23
#
#     mvar44 mvar45 mvar46 mvar47
# 0  0.85661     na      0      L
# ...

# %%
lead1.columns
# Out:
# Index(['application_key', 'mvar1', 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6',
#        'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
#        'mvar14', 'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20',
#        'mvar21', 'mvar22', 'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar27',
#        'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar33', 'mvar34',
#        'mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39', 'mvar40', 'mvar41',
#        'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47'],
#       dtype='object')

# %%
lead1_columns=[ 'mvar1', 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6',
       'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
       'mvar14', 'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20',
       'mvar21', 'mvar22', 'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar27',
       'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar33', 'mvar34',
       'mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39', 'mvar40', 'mvar41',
       'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46']

# %%
cvresult_df2=xgb.cv(plst, xgtrain_df2, num_boost_round=100, nfold=8, metrics=['auc'],
     early_stopping_rounds=50, stratified=True, seed=1301)

# %%
cvresult_df2
# Out:
#     test-auc-mean  test-auc-std  train-auc-mean  train-auc-std
# 0        0.807123      0.006046        0.814536       0.001398
# 1        0.814660      0.006973        0.822043       0.002168
# 2        0.817824      0.006717        0.825684       0.001876
# 3        0.820623      0.007762        0.829258       0.001754
# 4        0.822819      0.007188        0.831515       0.001922
# 5        0.823800      0.007334        0.832921       0.001855
# 6        0.824507      0.007644        0.833950       0.001740
# 7        0.825235      0.007454        0.834646       0.001599
# 8        0.825355      0.007535        0.835065       0.001543
# 9        0.825754      0.007518        0.835589       0.001470
# 10       0.826249      0.007639        0.836205       0.001467
# 11       0.826531      0.007376        0.836633       0.001553
# 12       0.826959      0.007270        0.837252       0.001571
# 13       0.827027      0.007339        0.837521       0.001490
# ...

# %%
for i in lead1.columns:
    lead1[i].replace(to_replace='missing',value=np.nan,inplace=True)

# %%
for i in lead1.columns:
    lead1[i].replace(to_replace='na',value=np.nan,inplace=True)

# %%
for i in lead1_columns:
    lead1[i]=lead1[i].astype(float)

# %%
lead1=pd.get_dummies(lead1,columns=['mvar47'],drop_first=True)

# %%
lead_df2=lead1.copy()

# %%
imp1=Imputer(missing_values='NaN',strategy='median',axis=0)

# %%
lead_df2.isnull().sum()
# Out:
# application_key        0
# mvar1               1150
# mvar2               1706
# mvar3                158
# mvar4                158
# mvar5                158
# mvar6               5807
# mvar7               2306
# mvar8               5807
# mvar9               3477
# mvar10               158
# mvar11             14026
# mvar12              4310
# mvar13              2565
# mvar14                 0
# mvar15             10051
# mvar16              5676
# mvar17              4890
# mvar18              4582
# mvar19                 1
# mvar20               158
# mvar21              6894
# mvar22              9081
# mvar23             12641
# mvar24              5777
# mvar25              2379
# mvar26              3200
# mvar27              3993
# mvar28               158
# mvar29               158
# mvar30             11449
# mvar31             17637
# mvar32              2379
# mvar33               539
# mvar34               158
# mvar35             10213
# mvar36               979
# ...

# %%
lead_df2.drop(columns='application_key',inplace=True)

# %%
col1_isna=['mvar1', 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6',
       'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
        'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20',
       'mvar21', 'mvar22', 'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar27',
       'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar33', 'mvar34',
       'mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39', 'mvar40', 'mvar41',
       'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46']

# %%
lead_df2.loc[:,col1_isna]=imp1.fit_transform(lead_df2.loc[:,col1_isna])

# %%
lead_df2.isnull().sum()
# Out:
# mvar1       0
# mvar2       0
# mvar3       0
# mvar4       0
# mvar5       0
# mvar6       0
# mvar7       0
# mvar8       0
# mvar9       0
# mvar10      0
# mvar11      0
# mvar12      0
# mvar13      0
# mvar14      0
# mvar15      0
# mvar16      0
# mvar17      0
# mvar18      0
# mvar19      0
# mvar20      0
# mvar21      0
# mvar22      0
# mvar23      0
# mvar24      0
# mvar25      0
# mvar26      0
# mvar27      0
# mvar28      0
# mvar29      0
# mvar30      0
# mvar31      0
# mvar32      0
# mvar33      0
# mvar34      0
# mvar35      0
# mvar36      0
# mvar37      0
# mvar38      0
# mvar39      0
# mvar40      0
# mvar41      0
# mvar42      0
# mvar43      0
# mvar44      0
# mvar45      0
# mvar46      0
# mvar47_L    0
# dtype: int64

# %%
xgtest_df2 = xgb.DMatrix(lead_df2)

# %%
pred_df2=model.predict(xgtest_df2)

# %%
pred_df2
# Out:
# array([0.0285764 , 0.07719103, 0.14481382, ..., 0.16538495, 0.04047669,
#        0.00732525], dtype=float32)

# %%
pred_df2[pred_df2<0.5]=0

# %%
pred_df2[pred_df2>=0.5]=1

# %%
pd.Series(pred_df2).value_counts()
# Out:
# 0.0    20891
# 1.0     4109
# dtype: int64

# %%
from sklearn.metrics import roc_auc_score

# %%
x_df2_train=xgb.DMatrix(x_df2)

# %%
x_df2_pred=model.predict(x_df2_train)

# %%
x_df2_pred[x_df2_pred<0.5]=0
x_df2_pred[x_df2_pred>=0.5]=1

# %%
roc_auc_score(y_df2,x_df2_pred)
# Out:
# 0.7471023455393152

# %%
lead1.application_key=lead1.application_key.astype(int)

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':pred_df2}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati.csv',header=False)

# %%
df1=pd.get_dummies(df1,columns=['mvar47'],drop_first=True)

# %%
df1.isnull().sum()
# Out:
# application_key        0
# mvar1               3639
# mvar2                  0
# mvar3                501
# mvar4                501
# mvar5                501
# mvar6                  0
# mvar7               7394
# mvar8              18964
# mvar9              11408
# mvar10               502
# mvar11             44819
# mvar12             14078
# mvar13              8352
# mvar14                 0
# mvar15             32067
# mvar16             18510
# mvar17             15846
# mvar18             14771
# mvar19                 4
# mvar20               502
# mvar21             22561
# mvar22             29124
# mvar23             40248
# mvar24             18902
# mvar25              7706
# mvar26             10610
# mvar27             13209
# mvar28               502
# mvar29               502
# mvar30             36417
# mvar31             56218
# mvar32              7706
# mvar33              1751
# mvar34               502
# mvar35             33014
# mvar36              2898
# ...

# %%
df3=df2.copy()

# %%
lead_df3=lead_df2.copy()

# %%
df3.drop(columns=['mvar5','mvar11','mvar21','mvar23','mvar30','mvar31','mvar40','mvar41','mvar45'],inplace=True)

# %%
lead_df3.drop(columns=['mvar5','mvar11','mvar21','mvar23','mvar30','mvar31','mvar40','mvar41','mvar45'],inplace=True)

# %%
x_df3=df3.loc[:,df3.columns!='default_ind']
y_df3=df3.loc[:,'default_ind']

# %%
xgtrain_df3 = xgb.DMatrix(x_df3, label=y_df3)

# %%
params={}
params["objective"] ="binary:logistic"
params["booster"]="gbtree"
params["learning_rate"] = 0.04
params["min_child_weight"] = 6
params["subsample"] = 0.8
params['alpha']=0.2
params["colsample_bytree"] = 0.8
params["silent"] = 1
params["max_depth"] = 7
params["seed"] = 0
plst = list(params.items())

# %%
model_df3=xgb.train(plst,xgtrain_df3,num_boost_round=700)

# %%
cvresult_df3=xgb.cv(plst, xgtrain_df3, num_boost_round=200, nfold=8, metrics=['auc'],
     early_stopping_rounds=50, stratified=True, seed=1301)

# %%
cvresult_df3
# Out:
#      test-auc-mean  test-auc-std  train-auc-mean  train-auc-std
# 0         0.808663      0.008042        0.821129       0.002671
# 1         0.815729      0.008577        0.829005       0.003372
# 2         0.820149      0.007015        0.834057       0.002423
# 3         0.821868      0.006783        0.836301       0.002563
# 4         0.823436      0.006472        0.838263       0.002697
# 5         0.824703      0.006796        0.839350       0.002322
# 6         0.825917      0.006645        0.840495       0.002182
# 7         0.826540      0.006671        0.841380       0.002307
# 8         0.827073      0.006780        0.842067       0.001908
# 9         0.827504      0.006780        0.842607       0.002000
# 10        0.828002      0.006588        0.843257       0.002183
# 11        0.828189      0.006499        0.843737       0.002168
# 12        0.828523      0.006534        0.844155       0.002153
# 13        0.828658      0.006433        0.844593       0.002235
# ...

# %%
x_df3_train=xgb.DMatrix(x_df3)

# %%
roc_auc_score(y_df3,model_df3.predict(x_df3_train))
# Out:
# 0.9302429341966744

# %%
xgtest_df3=xgb.DMatrix(lead_df3)

# %%
pred_df3=model_df3.predict(xgtest_df3)

# %%
pred_df3
# Out:
# array([0.04659662, 0.06728798, 0.08227778, ..., 0.09920238, 0.0400711 ,
#        0.00682693], dtype=float32)

# %%
pred_df3[pred_df3<0.5]=0
pred_df3[pred_df3>=0.5]=1

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':pred_df3}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_2.csv',header=False)

# %%
pd.Series(pred_df3).value_counts()
# Out:
# 0.0    21050
# 1.0     3950
# dtype: int64

# %%
df4=df3.copy()
lead_df41=lead_df3.copy()

# %%
df4.describe()
# Out:
#               mvar1         mvar2         mvar3         mvar4          mvar6  \
# count  80000.000000  80000.000000  80000.000000  80000.000000   80000.000000
# mean    1745.790450      1.066291      5.249762      0.471545    1296.237425
# std       92.366132      1.593692     10.788702      1.791018    3282.623599
# min     1493.000000      0.000000      0.000000      0.000000       0.000000
# 25%     1683.000000      0.160100      0.000000      0.000000      90.000000
# 50%     1742.000000      0.538900      0.300000      0.000000     297.000000
# 75%     1806.000000      1.358400      6.373000      0.000000     788.000000
# max     1950.000000     44.630100    286.858000    114.696000  136595.000000
#
#               mvar7          mvar8         mvar9        mvar10         mvar12  \
# count  8.000000e+04   80000.000000  8.000000e+04  8.000000e+04   80000.000000
# mean   1.661344e+04    5755.394138  3.125593e+04  3.036059e+04    6394.653500
# ...

# %%
xgb.plot_importance(model)
plt.rcParams['figure.figsize'] = [10,10]
plt.show()

# %%
from xgboost.sklearn import XGBClassifier

# %%
xgb1 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=5,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)

# %%
xgb1.fit(x_df3,y_df3)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=5, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=4, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=27, silent=True,
#        subsample=0.8)

# %%
roc_auc_score(y_df3,xgb1.predict(x_df3))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.8148065987970411

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(xgb1,x_df3,y_df3,scoring='roc_auc',cv=8).mean()
# Out:
# 0.8307120859665329

# %%
xgb1_pred=xgb1.predict(lead_df3)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
pd.Series(xgb1_pred).value_counts()
# Out:
# 0    21120
# 1     3880
# dtype: int64

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':xgb1_pred}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_3.csv',header=False)

# %%
df4.corr()
# Out:
#                 mvar1     mvar2     mvar3     mvar4     mvar6     mvar7  \
# mvar1        1.000000 -0.256224 -0.497789 -0.267180  0.399901  0.266474
# mvar2       -0.256224  1.000000  0.120972  0.089591 -0.145104 -0.091945
# mvar3       -0.497789  0.120972  1.000000  0.369375 -0.127995 -0.085671
# mvar4       -0.267180  0.089591  0.369375  1.000000 -0.073698 -0.046230
# mvar6        0.399901 -0.145104 -0.127995 -0.073698  1.000000  0.204073
# mvar7        0.266474 -0.091945 -0.085671 -0.046230  0.204073  1.000000
# mvar8        0.557929 -0.177353 -0.193187 -0.107875  0.508145  0.352788
# mvar9        0.495168 -0.147461 -0.191957 -0.111055  0.262408  0.318502
# mvar10       0.414815 -0.119838 -0.145581 -0.074035  0.252649  0.890262
# mvar12       0.158849 -0.020493 -0.145556 -0.076768 -0.024221  0.132393
# mvar13       0.223325 -0.061538 -0.097108 -0.055164  0.178367  0.311282
# mvar14       0.000025 -0.003896 -0.001201 -0.001147 -0.000507  0.002839
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df5=df2.copy()
lead_df5=lead_df2.copy()

# %%
x_df5=df5.loc[:,df5.columns!='default_ind']
y_df5=df5.loc[:,'default_ind']

# %%
 sc = StandardScaler()
x_df5_std = sc.fit_transform(x_df5)
lead_df5_std = sc.transform(lead_df5)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
x_df5_pca = pca.fit_transform(x_df5_std)
lead_df5_pca = pca.transform(lead_df5_std)

# %%
xgtrain_df5_pca = xgb.DMatrix(x_df5_pca, label=y_df5)

# %%
xgtest_df5_pca=xgb.DMatrix(lead_df5_pca)

# %%
model_df5=xgb.train(plst,xgtrain_df5_pca,num_boost_round=700)

# %%
cvresult_df5=xgb.cv(plst, xgtrain_df5_pca, num_boost_round=100, nfold=7, metrics=['auc'],
     early_stopping_rounds=50, stratified=True, seed=1301)

# %%
roc_auc_score(y_df5,model_df5.predict(xgb.DMatrix(x_df5_pca)))
# Out:
# 0.8222277283105267

# %%
pred_df5=model_df5.predict(xgtest_df5_pca)

# %%
pred_df5[pred_df5<0.5]=0
pred_df5[pred_df5>=0.5]=1

# %%
pd.Series(pred_df5).value_counts()
# Out:
# 0.0    21797
# 1.0     3203
# dtype: int64

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':pred_df5}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_4.csv',header=False)

# %%
df2.head()
# Out:
#     mvar1   mvar2  mvar3  mvar4  mvar5   mvar6    mvar7   mvar8    mvar9  \
# 0  1696.0  1.6541  0.000    0.0    0.0     0.0   6015.0   322.0  40369.0
# 1  1846.0  0.8095  0.000    0.0    0.0   102.0   7532.0  3171.0  18234.0
# 2  1745.0  0.4001  0.000    0.0    0.0   297.0   2536.0  2478.0  14171.0
# 3  1739.0  0.2193  0.000    0.0    0.0  1982.0  26440.0  4955.0  20316.0
# 4  1787.0  0.0118  0.225    0.0    0.0  5451.0   5494.0  5494.0   7987.0
#
#     mvar10    ...     mvar39   mvar40   mvar41   mvar42  mvar43   mvar44  \
# 0  18414.0    ...        1.0   73.780  82.5470  0.08696    10.0  0.63899
# 1  13664.0    ...        0.0   99.129  78.8835  0.00000    13.0  0.63836
# 2   2536.0    ...        0.0  100.000  29.2900  0.00000     1.0  1.00000
# 3  37013.0    ...        0.0   96.272  78.8835  0.15385     3.0  0.53241
# 4   4696.0    ...        0.0  115.019  78.8835  0.00000     1.0  0.92665
#
#    mvar45  mvar46  default_ind  mvar47_L
# 0     0.0     0.0            0         0
# ...

# %%
df4.mvar16=np.sqrt(df4.mvar16)

# %%
plt.hist(df4.mvar14,range=(df4.mvar14.min(),df4.mvar14.max()))
plt.xlim(df4.mvar14.min(),1000000000)
# Out:
# (0, 1000000000)

# %%
sns.boxplot(df4.mvar14)

# %%
df4['net_worth']=df4.mvar15-df4.mvar14-df4.mvar13

# %%
df4['number_cards']=df4.mvar16+df4.mvar17+df4.mvar18

# %%
df4['75%_number_cards']=df4.mvar19+df4.mvar20

# %%
df4["number_missed_1payment"]=df4.mvar35+df4.mvar34

# %%
df4["avg_maxcredit_avail"]=(df4.mvar7+df4.mvar8)/2

# %%
df4.drop(columns='mvar4',inplace=True)

# %%
x_df4=df4.loc[:,df4.columns!='default_ind']
y_df4=df4.loc[:,'default_ind']

# %%
params={}
params["objective"] ="binary:logistic"
params["booster"]="gbtree"
params["learning_rate"] = 0.02
params["min_child_weight"] = 6
params["subsample"] = 0.8
params["colsample_bytree"] = 0.8
params["silent"] = 1
params["max_depth"] = 10
params["seed"] = 0
plst = list(params.items())

# %%
xgtrain_df4 = xgb.DMatrix(x_df4, label=y_df4)

# %%
model_df4=xgb.train(plst,xgtrain_df4,num_boost_round=800)

# %%
cvresult_df4=xgb.cv(plst, xgtrain_df4, num_boost_round=100, nfold=6, metrics=['auc'],
     early_stopping_rounds=50, stratified=True, seed=1301)

# %%
roc_auc_score(y_df4,model_df4.predict(xgb.DMatrix(x_df4)))
# Out:
# 0.9637483115034605

# %%
lead_df41['net_worth']=lead_df41.mvar15-lead_df41.mvar14-lead_df41.mvar13
lead_df41['number_cards']=lead_df41.mvar16+lead_df41.mvar17+lead_df41.mvar18
lead_df41['75%_number_cards']=lead_df41.mvar19+lead_df41.mvar20
lead_df41["number_missed_1payment"]=lead_df41.mvar35+lead_df41.mvar34
lead_df41["avg_maxcredit_avail"]=(lead_df41.mvar7+lead_df41.mvar8)/2
lead_df41.drop(columns='mvar4',inplace=True)

# %%
xgtest_df4=xgb.DMatrix(lead_df41)

# %%
pred_df4=model_df4.predict(xgtest_df4)

# %%
pred_df4[pred_df4<0.5]=0
pred_df4[pred_df4>=0.5]=1

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':pred_df4}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_5.csv',header=False)

# %%
df6=df1.copy()
lead_df6=lead1.copy()

# %%
df6.fillna(-999,inplace=True)
lead_df6.fillna(-999,inplace=True)

# %%
lead_df6['net_worth']=lead_df6.mvar15-lead_df6.mvar14-lead_df6.mvar13
lead_df6['number_cards']=lead_df6.mvar16+lead_df6.mvar17+lead_df6.mvar18
lead_df6['75%_number_cards']=lead_df6.mvar19+lead_df6.mvar20
lead_df6["number_missed_1payment"]=lead_df6.mvar35+lead_df6.mvar34
lead_df6["avg_maxcredit_avail"]=(lead_df6.mvar7+lead_df6.mvar8)/2

# %%
df6['net_worth']=df6.mvar15-df6.mvar14-df6.mvar13
df6['number_cards']=df6.mvar16+df6.mvar17+df6.mvar18
df6['75%_number_cards']=df6.mvar19+df6.mvar20
df6["number_missed_1payment"]=df6.mvar35+df6.mvar34
df6["avg_maxcredit_avail"]=(df6.mvar7+df6.mvar8)/2

# %%
params = {}
params["objective"] = "binary:logitraw"
params['booster']='gbtree'
params["eta"] = 0.02
params["min_child_weight"] = 9
params["subsample"] = 0.8
params["colsample_bytree"] = 0.8
params["silent"] = 0
params["max_depth"] = 10
params["seed"] = 0
params['eval_metric'] = "auc"
plst1 = list(params.items())

# %%
plst1
# Out:
# [('objective', 'binary:logitraw'),
#  ('booster', 'gbtree'),
#  ('eta', 0.02),
#  ('min_child_weight', 9),
#  ('subsample', 0.8),
#  ('colsample_bytree', 0.8),
#  ('silent', 0),
#  ('max_depth', 10),
#  ('seed', 0),
#  ('eval_metric', 'auc')]

# %%
lead_df6.head()
# Out:
#    application_key   mvar1   mvar2  mvar3  mvar4  mvar5  mvar6    mvar7  \
# 0           350053  1753.0  0.5001  0.000    0.0    0.0  206.0  19179.0
# 1           350054  1894.0  1.9701  0.000    0.0    0.0  297.0  19820.0
# 2           350055  1774.0  0.1718  0.000    0.0    0.0  197.0   2563.0
# 3           350056  1586.0  0.1123  5.299    0.0    0.0 -999.0   -999.0
# 4           350057  1832.0  1.4442  0.000    0.0    0.0  179.0   7577.0
#
#      mvar8     mvar9         ...           mvar43     mvar44  mvar45  mvar46  \
# 0    206.0   14221.0         ...              3.0    0.85661  -999.0     0.0
# 1  19820.0  176895.0         ...             15.0    0.94391     0.0     0.0
# 2    877.0    8869.0         ...              3.0    0.76467     0.0     0.0
# 3   -999.0    -999.0         ...              0.0 -999.00000  -999.0  -999.0
# 4    179.0   21059.0         ...             23.0    0.79190     0.0     0.0
#
#    mvar47_L  net_worth  number_cards  75%_number_cards  \
# ...

# %%
x_df6=df6.loc[:,df6.columns!='default_ind']
y_df6=df6.loc[:,'default_ind']

# %%
xgtrain_df6=xgb.DMatrix(x_df6,label=y_df6)

# %%
xgtest_df6=xgb.DMatrix(lead_df6)

# %%
model_df6=xgb.train(plst1,xgtrain_df6,750)

# %%
cvresult_df6=xgb.cv(plst1, xgtrain_df6, num_boost_round=100, nfold=6, metrics=['auc'],
     early_stopping_rounds=50, stratified=True, seed=1301)

# %%
pred_df6=model_df6.predict(xgtest_df6)

# %%
pred_df6
# Out:
# array([-3.2821555, -3.141839 , -2.463689 , ..., -1.7540197, -2.7622743,
#        -4.963597 ], dtype=float32)

# %%
pred_df6=1/(1+np.exp(-pred_df6))

# %%
pred_df6[pred_df6<0.5]=0
pred_df6[pred_df6>=0.5]=1

# %%
pd.Series(pred_df6).value_counts()
# Out:
# 0.0    21186
# 1.0     3814
# dtype: int64

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':pred_df6}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_6.csv',header=False)

# %%
pred_df2a=model.predict(xgtest_df2)

# %%
pred_df3a=model_df3.predict(xgtest_df3)

# %%
pred_df4a=model_df4.predict(xgtest_df4)

# %%
weighted_pred=(0.4*pred_df2a)+(0.3*pred_df3a)+(0.3*pred_df4a)

# %%
weighted_pred1=weighted_pred.copy()

# %%
weighted_pred1[weighted_pred1<0.4]=0
weighted_pred1[weighted_pred1>=0.4]=1

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':weighted_pred1}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_7.csv',header=False)

# %%
weighted_pred2=weighted_pred.copy()

# %%
weighted_pred2[weighted_pred2<0.2]=0
weighted_pred2[weighted_pred2>=0.2]=1

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':weighted_pred2}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_8.csv',header=False)

# %%
weighted_pred[weighted_pred<0.5]=0
weighted_pred[weighted_pred>=0.5]=1

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':weighted_pred}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_9.csv',header=False)

# %%
df8=df2.copy()
lead_df8=lead_df2.copy()

# %%
lead_df8.shape
# Out:
# (25000, 47)

# %%
df8['avg_utilization']=(df8.mvar40+df8.mvar41)/2

# %%
df8.drop(columns=['mvar40','mvar41'],inplace=True)

# %%
lead_df8['avg_utilization']=(lead_df8.mvar40+lead_df8.mvar41)/2

# %%
lead_df8.drop(columns=['mvar40','mvar41'],inplace=True)

# %%
df8['avg_utilization']=(df8.mvar40+df8.mvar41)/2

# %%
lead_df8['net_savings']=lead_df8.mvar14-lead_df8.mvar13

# %%
df8['weighted_severity']=(0.5*df8.mvar3+0.3*df8.mvar4+0.2*df8.mvar5)

# %%
lead_df8['weighted_severity']=(0.5*lead_df8.mvar3+0.3*lead_df8.mvar4+0.2*lead_df8.mvar5)

# %%
df8.drop(columns=['mvar3','mvar4','mvar5'],inplace=True)

# %%
lead_df8.drop(columns=['mvar3','mvar4','mvar5'],inplace=True)

# %%
df8.mvar2=np.sqrt(df8.mvar2)

# %%
lead_df8.mvar2=np.sqrt(lead_df8.mvar2)

# %%
xgb.plot_importance(model_df6)
plt.rcParams['figure.figsize'] = [10,10]
plt.show()

# %%
df8.mvar29=df8.mvar29/30

# %%
df8.mvar29=np.sqrt(df8.mvar29)

# %%
lead_df8.mvar29=lead_df8.mvar29/30

# %%
lead_df8.mvar29=np.sqrt(lead_df8.mvar29)

# %%
days_col=['mvar25','mvar26','mvar27','mvar28','mvar30','mvar31']

# %%
for i in days_col:
    df8[i]=df8[i]/30

# %%
for i in days_col:
    lead_df8[i]=lead_df8[i]/30

# %%
days_col1=['mvar25','mvar26','mvar27','mvar28','mvar31']

# %%
for i in days_col1:
    df8[i]=np.sqrt(df8[i])

# %%
for i in days_col1:
    lead_df8[i]=np.sqrt(lead_df8[i])

# %%
x_df8=df8.loc[:,df8.columns!='default_ind']
y_df8=df8.loc[:,'default_ind']

# %%
xgtrain_df8=xgb.DMatrix(x_df8,label=y_df8)

# %%
xgtest_df8=xgb.DMatrix(lead_df8)

# %%
params = {}
params["objective"] = "binary:logistic"
params['booster']='gbtree'
params['gamma']=0.3
params["eta"] = 0.03
params["min_child_weight"] = 8
params["subsample"] = 0.8
params["colsample_bytree"] = 0.7
params["silent"] = 1
params["max_depth"] = 10
params["seed"] = 0
params['eval_metric'] = "auc"
plst2 = list(params.items())

# %%
cvresult_df8=xgb.cv(plst2, xgtrain_df8, num_boost_round=100, nfold=6, metrics=['auc'],
     early_stopping_rounds=50, stratified=True, seed=1301)

# %%
model_df8=xgb.train(plst2,xgtrain_df8,750)

# %%
x_df8.columns
# Out:
# Index(['mvar1', 'mvar2', 'mvar6', 'mvar7', 'mvar8', 'mvar9', 'mvar10',
#        'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15', 'mvar16', 'mvar17',
#        'mvar18', 'mvar19', 'mvar20', 'mvar21', 'mvar22', 'mvar23', 'mvar24',
#        'mvar25', 'mvar26', 'mvar27', 'mvar28', 'mvar29', 'mvar30', 'mvar31',
#        'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar37', 'mvar38',
#        'mvar39', 'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47_L',
#        'avg_utilization', 'net_savings', 'weighted_severity'],
#       dtype='object')

# %%
cols=['mvar1', 'mvar2', 'mvar6', 'mvar7', 'mvar8', 'mvar9', 'mvar10',
       'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15', 'mvar16', 'mvar17',
       'mvar18', 'mvar19', 'mvar20', 'mvar21', 'mvar22', 'mvar23', 'mvar24',
       'mvar25', 'mvar26', 'mvar27', 'mvar28', 'mvar29', 'mvar30', 'mvar31',
       'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar37', 'mvar38',
       'mvar39', 'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47_L',
       'avg_utilization', 'net_savings', 'weighted_severity']

# %%
lead_df8=lead_df8[cols]

# %%
xgtest_df8a=xgb.DMatrix(lead_df8)

# %%
pred_df8=model_df8.predict(xgtest_df8a)

# %%
pred_df8[pred_df8<0.5]=0
pred_df8[pred_df8>=0.5]=1

# %%
pd.Series(pred_df8).value_counts()
# Out:
# 0.0    20923
# 1.0     4077
# dtype: int64

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':pred_df8}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_10.csv',header=False)

# %%
weighted_pred2=0.4*pred_df2+0.4*pred_df8+0.3*pred_df3

# %%
weighted_pred2[weighted_pred<0.5]=0
weighted_pred2[weighted_pred>=0.5]=1

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':weighted_pred2}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_11.csv',header=False)

# %%
weighted_pred3=0.4*pred_df8+0.3*pred_df3+0.3*pred_df4

# %%
weighted_pred3[weighted_pred3<0.5]=0
weighted_pred3[weighted_pred3>=0.5]=1

# %%
pd.DataFrame({'lead1.application_key':lead1.application_key,'default_ind':weighted_pred3}).set_index("lead1.application_key").to_csv('mahi_ditya_IITGuwahati_12.csv',header=False)

# %%
eva=pd.read_csv("analyze_eval.csv")

# %%
eva.head()
# Out:
#    application_key mvar1   mvar2   mvar3  mvar4  mvar5 mvar6   mvar7  mvar8  \
# 0           570075  1860  0.4668   0.212    0.0    0.0  1621  151211  22298
# 1           570076  1797     NaN   0.000    0.0    0.0   920    8124    920
# 2           570077  1826  0.0423   0.000    0.0    0.0  3478    7209   3964
# 3           570078  1656  0.2726  41.623    0.0    0.0  4955    4955   4955
# 4           570079  1915     NaN   0.000    0.0    0.0  6918    7433   6918
#
#     mvar9  ...   mvar38 mvar39   mvar40   mvar41   mvar42 mvar43   mvar44  \
# 0  161588  ...        0      0  missing  missing        0     10  0.95597
# 1   30429  ...        1      0  missing   14.888        0      4  0.45250
# 2   16054  ...        2      0   37.586   64.002  0.09091      7  0.92384
# 3   65010  ...        0      0  missing  missing  0.52632      0      NaN
# 4    7433  ...        0      0  missing  missing        0      2  1.00000
#
#   mvar45 mvar46 mvar47
# 0      0     na      C
# ...

# %%
for i in eva.columns:
    eva[i].replace(to_replace='missing',value=np.nan,inplace=True)

# %%
for i in eva.columns:
    eva[i].replace(to_replace='na',value=np.nan,inplace=True)

# %%
eva.isnull().sum()
# Out:
# application_key        0
# mvar1               1172
# mvar2               1954
# mvar3                170
# mvar4                170
# mvar5                170
# mvar6               6227
# mvar7               2453
# mvar8               6240
# mvar9               3609
# mvar10               170
# mvar11             14390
# mvar12              4587
# mvar13              4579
# mvar14                 0
# mvar15             10237
# mvar16              6090
# mvar17              5195
# mvar18              4791
# mvar19                 7
# mvar20               170
# mvar21              7387
# mvar22              9831
# mvar23             13399
# mvar24              6117
# mvar25              2375
# mvar26              3554
# mvar27              4399
# mvar28               170
# mvar29               170
# mvar30             11597
# mvar31             17827
# mvar32              2375
# mvar33               616
# mvar34               170
# mvar35             11406
# mvar36              1012
# ...

# %%
eva1=eva.copy()

# %%
eva1.columns
# Out:
# Index(['application_key', 'mvar1', 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6',
#        'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
#        'mvar14', 'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20',
#        'mvar21', 'mvar22', 'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar27',
#        'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar33', 'mvar34',
#        'mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39', 'mvar40', 'mvar41',
#        'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47'],
#       dtype='object')

# %%
eva_col=['mvar1', 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6',
       'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13',
       'mvar14', 'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20',
       'mvar21', 'mvar22', 'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar27',
       'mvar28', 'mvar29', 'mvar30', 'mvar31', 'mvar32', 'mvar33', 'mvar34',
       'mvar35', 'mvar36', 'mvar37', 'mvar38', 'mvar39', 'mvar40', 'mvar41',
       'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46']

# %%
for i in eva_col:
    eva1[i]=eva1[i].astype(float)

# %%
eva2=eva1.copy()

# %%
imp_eva2=Imputer(missing_values='NaN',strategy='median',axis=0)

# %%
eva2.loc[:,eva_col]=imp_eva2.fit_transform(eva2.loc[:,eva_col])

# %%
eva2=pd.get_dummies(eva2,columns=['mvar47'],drop_first=True)

# %%
eva2.drop(columns=['application_key'],inplace=True)

# %%
eva2_dm=xgb.DMatrix(eva2)

# %%
pred_eva2=model.predict(eva2_dm)

# %%
pred_eva2a=model.predict(eva2_dm)

# %%
pred_eva2[pred_eva2<0.5]=0
pred_eva2[pred_eva2>=0.5]=1

# %%
eva3=eva1.copy()

# %%
eva3['avg_utilization']=(eva3.mvar40+eva3.mvar41)/2

# %%
eva3['net_savings']=eva3.mvar14-eva3.mvar13

# %%
eva3['weighted_severity']=(0.5*eva3.mvar3+0.3*eva3.mvar4+0.2*eva3.mvar5)

# %%
eva3.drop(columns=['mvar3','mvar4','mvar5','mvar40','mvar41'],inplace=True)

# %%
days_col_eva=['mvar25','mvar26','mvar27','mvar28','mvar29','mvar30','mvar31']

# %%
for i in days_col_eva:
    eva3[i]=eva3[i]/30

# %%
days_col_eva2=['mvar25','mvar26','mvar27','mvar28','mvar29','mvar31']

# %%
for i in days_col_eva2:
    eva3[i]=np.sqrt(eva3[i])

# %%
eva3.mvar2=np.sqrt(eva3.mvar2)

# %%
eva3.drop(columns=['application_key'],inplace=True)

# %%
x_df8.columns
# Out:
# Index(['mvar1', 'mvar2', 'mvar6', 'mvar7', 'mvar8', 'mvar9', 'mvar10',
#        'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15', 'mvar16', 'mvar17',
#        'mvar18', 'mvar19', 'mvar20', 'mvar21', 'mvar22', 'mvar23', 'mvar24',
#        'mvar25', 'mvar26', 'mvar27', 'mvar28', 'mvar29', 'mvar30', 'mvar31',
#        'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar37', 'mvar38',
#        'mvar39', 'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47_L',
#        'avg_utilization', 'net_savings', 'weighted_severity'],
#       dtype='object')

# %%
eva3.columns
# Out:
# Index(['mvar1', 'mvar2', 'mvar6', 'mvar7', 'mvar8', 'mvar9', 'mvar10',
#        'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15', 'mvar16', 'mvar17',
#        'mvar18', 'mvar19', 'mvar20', 'mvar21', 'mvar22', 'mvar23', 'mvar24',
#        'mvar25', 'mvar26', 'mvar27', 'mvar28', 'mvar29', 'mvar30', 'mvar31',
#        'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar37', 'mvar38',
#        'mvar39', 'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47',
#        'avg_utilization', 'net_savings', 'weighted_severity'],
#       dtype='object')

# %%
eva3=pd.get_dummies(eva3,columns=['mvar47'],drop_first=True)

# %%
eva3_dm=xgb.DMatrix(eva3)

# %%
x_df8.columns
# Out:
# Index(['mvar1', 'mvar2', 'mvar6', 'mvar7', 'mvar8', 'mvar9', 'mvar10',
#        'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15', 'mvar16', 'mvar17',
#        'mvar18', 'mvar19', 'mvar20', 'mvar21', 'mvar22', 'mvar23', 'mvar24',
#        'mvar25', 'mvar26', 'mvar27', 'mvar28', 'mvar29', 'mvar30', 'mvar31',
#        'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar37', 'mvar38',
#        'mvar39', 'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47_L',
#        'avg_utilization', 'net_savings', 'weighted_severity'],
#       dtype='object')

# %%
cols_eva3=['mvar1', 'mvar2', 'mvar6', 'mvar7', 'mvar8', 'mvar9', 'mvar10',
       'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15', 'mvar16', 'mvar17',
       'mvar18', 'mvar19', 'mvar20', 'mvar21', 'mvar22', 'mvar23', 'mvar24',
       'mvar25', 'mvar26', 'mvar27', 'mvar28', 'mvar29', 'mvar30', 'mvar31',
       'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar37', 'mvar38',
       'mvar39', 'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46', 'mvar47_L',
       'avg_utilization', 'net_savings', 'weighted_severity']

# %%
eva3=eva3[cols_eva3]

# %%
pred_eva3=model_df8.predict(eva3_dm)

# %%
pred_eva3a=model_df8.predict(eva3_dm)

# %%
pred_eva3[pred_eva3<0.5]=0
pred_eva3[pred_eva3>=0.5]=1

# %%
eva4=eva1.copy()

# %%
eva4.drop(columns=['application_key','mvar5','mvar11','mvar21','mvar23','mvar30','mvar31','mvar40','mvar41','mvar45'],
          inplace=True)

# %%
eva4=pd.get_dummies(eva4,columns=['mvar47'],drop_first=True)

# %%
x_df3.shape
# Out:
# (80000, 38)

# %%
eva4_dm=xgb.DMatrix(eva4)

# %%
pred_eva4=model_df3.predict(eva4_dm)

# %%
pred_eva4[pred_eva4<0.5]=0
pred_eva4[pred_eva4>=0.5]=1

# %%
pred_eva4a=model_df3.predict(eva4_dm)

# %%
weighted_pred_eva=0.4*pred_eva2a+0.3*pred_eva3a+0.3*pred_eva4a

# %%
weighted_pred_eva1=weighted_pred_eva.copy()

# %%
weighted_pred_eva1[weighted_pred_eva1<0.5]=0
weighted_pred_eva1[weighted_pred_eva1>=0.5]=1

# %%
pd.DataFrame({'application_key':eva1.application_key,'default_ind':weighted_pred_eva1,'probability':weighted_pred_eva}).set_index("application_key").to_csv('mahi_ditya_IITGuwahati_13.csv',header=False)
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x000002BF5DC6C7B8>>
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\site-packages\xgboost\core.py", line 366, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'

# %%
final=pd.read_csv('mahi_ditya_IITGuwahati_13.csv',header=None)

# %%
final.sort_values(by=[1,2],ascending=True).set_index(0).to_csv("final.csv",header=False)

# %%
final.columns
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
df8.columns
# Out:
# Index(['mvar1', 'mvar2', 'mvar6', 'mvar7', 'mvar8', 'mvar9', 'mvar10',
#        'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15', 'mvar16', 'mvar17',
#        'mvar18', 'mvar19', 'mvar20', 'mvar21', 'mvar22', 'mvar23', 'mvar24',
#        'mvar25', 'mvar26', 'mvar27', 'mvar28', 'mvar29', 'mvar30', 'mvar31',
#        'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar37', 'mvar38',
#        'mvar39', 'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46',
#        'default_ind', 'mvar47_L', 'avg_utilization', 'net_savings',
#        'weighted_severity'],
#       dtype='object')

# %%
final.sort_values(by=[1,2],ascending=False)
# Out:
#             0    1         2
# 22495  592570  1.0  0.961999
# 18658  588733  1.0  0.958473
# 8070   578145  1.0  0.957296
# 22691  592766  1.0  0.953632
# 23964  594039  1.0  0.950341
# 22789  592864  1.0  0.947651
# 23669  593744  1.0  0.947143
# 17976  588051  1.0  0.944438
# 10216  580291  1.0  0.943599
# 3611   573686  1.0  0.942101
# 22434  592509  1.0  0.941160
# 8960   579035  1.0  0.941104
# 16362  586437  1.0  0.940705
# 18101  588176  1.0  0.939888
# 8899   578974  1.0  0.939779
# 22003  592078  1.0  0.938987
# 16986  587061  1.0  0.938234
# 17739  587814  1.0  0.938222
# 8169   578244  1.0  0.936652
# 5872   575947  1.0  0.936527
# 23921  593996  1.0  0.935088
# 22787  592862  1.0  0.933831
# 829    570904  1.0  0.932831
# 20474  590549  1.0  0.932447
# 11172  581247  1.0  0.931592
# 5616   575691  1.0  0.930673
# 11817  581892  1.0  0.930363
# 13309  583384  1.0  0.928110
# 19069  589144  1.0  0.927713
# 4123   574198  1.0  0.926193
# ...       ...  ...       ...
# ...
